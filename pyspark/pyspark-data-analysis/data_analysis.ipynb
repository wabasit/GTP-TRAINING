# %%
import pyspark

# %%
from data_extraction import fetch_apis
from utility_functions import SCHEMA, parse_movie_data, \
     clean_data, calculate_financial_metrics, get_spark_session

# %%
spark = get_spark_session()

# %%
movie_ids_to_fetch = [
        0, 299534, 19995, 140607, 299536, 597, 135397,
        420818, 24428, 168259, 99861, 284054, 12445,
        181808, 330457, 351286, 109445, 321612, 260513
    ]

# %%
movie_schema = SCHEMA

# %%
raw_df = fetch_apis(movie_ids_to_fetch, movie_schema)

# %%
clean_df = clean_data(raw_df)

# %%
clean_df.show()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 clean_df.show()
#
# File c:\Users\dell\anaconda3\Lib\site-packages\pyspark\sql\dataframe.py:947, in DataFrame.show(self, n, truncate, vertical)
#     887 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
#     888     """Prints the first ``n`` rows to the console.
#     889
#     890     .. versionadded:: 1.3.0
#    (...)
#     945     name | Bob
#     946     """
# --> 947     print(self._show_string(n, truncate, vertical))
#
# File c:\Users\dell\anaconda3\Lib\site-packages\pyspark\sql\dataframe.py:965, in DataFrame._show_string(self, n, truncate, vertical)
#     959     raise PySparkTypeError(
#     960         error_class="NOT_BOOL",
#     961         message_parameters={"arg_name": "vertical", "arg_type": type(vertical).__name__},
#     962     )
# ...

# %%
# spark.stop()
